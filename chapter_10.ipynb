# %%
import sys
import numpy as np
import scipy.stats
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(123)

# plot style
plt.style.use("seaborn-v0_8")
# print(plt.style.available)

# the "R4" palette
_colours = ["#000000f0", "#DF536Bf0", "#61D04Ff0", "#2297E6f0",
            "#28E2E5f0", "#CD0BBCf0", "#F5C710f0", "#999999f0"]

_linestyles = ["solid", "dashed", "dashdot", "dotted"]

# A different plotting style for each plotted line
plt.rcParams["axes.prop_cycle"] = plt.cycler(color=_colours, linestyle=_linestyles*2)
plt.rcParams["patch.facecolor"] = _colours[0]

# Python version
print(f"sys: {sys.version}")
print(f"numpy: {np.__version__}")
print(f"scipy: {scipy.__version__}")
print(f"pandas: {pd.__version__}")
print(f"matplotlib: {matplotlib.__version__}")
print(f"seaborns {sns.__version__}")
# Out:
# sys: 3.9.5 (tags/v3.9.5:0a7dcbd, May  3 2021, 17:27:52) [MSC v.1928 64 bit (AMD64)]
# numpy: 1.24.2
# scipy: 1.10.1
# pandas: 1.5.3
# matplotlib: 3.7.1
# seaborns 0.12.2

# %% [markdown]
# # Creating DataFrames

# %%
df = pd.DataFrame(
    np.random.rand(4, 3),
    columns=["a", "b", "c"]
)

df
# Out:
#           a         b         c
# 0  0.696469  0.286139  0.226851
# 1  0.551315  0.719469  0.423106
# 2  0.980764  0.684830  0.480932
# 3  0.392118  0.343178  0.729050

# %%
df = pd.DataFrame(dict(
    a = np.round(np.random.rand(5), 2),
    b = [1, 2.5, np.nan, 4, np.nan],
    c = [True, True, False, False, True],
    d = ["A", "B", "C", None, "E"],
    e = ["spam", "spam", "bacon", "spam", "eggs"],
    f = np.array([
        "2021-01-01", "2022-02-02", "2023-03-03", "2024-04-04", "2025-05-05"],
        dtype="datetime64[D]"),
    g = [["spam"], ["bacon", "spam"], None, ["eggs", "bacon", "spam"], ["ham"]],
))

df
# Out:
#       a    b      c     d      e          f                    g
# 0  0.44  1.0   True     A   spam 2021-01-01               [spam]
# 1  0.06  2.5   True     B   spam 2022-02-02        [bacon, spam]
# 2  0.40  NaN  False     C  bacon 2023-03-03                 None
# 3  0.74  4.0  False  None   spam 2024-04-04  [eggs, bacon, spam]
# 4  0.18  NaN   True     E   eggs 2025-05-05                [ham]

# %%
print(f"Shape: {df.shape}")
print(f"\ndtype:\n{df.dtypes}")
# Out:
# Shape: (5, 7)
#
# dtype:
# a           float64
# b           float64
# c              bool
# d            object
# e            object
# f    datetime64[ns]
# g            object
# dtype: object

# %% [markdown]
# # DataFrames from data

# %%
body = pd.read_csv("data/nhanes_adult_female_bmx_2020.csv", comment="#")

# %%
body.head()
# Out:
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 0   97.1  160.2     34.7    40.8     35.8   126.1     117.9
# 1   91.1  152.7     33.5    33.0     38.5   125.5     103.1
# 2   73.0  161.2     37.4    38.0     31.8   106.2      92.0
# 3   61.7  157.4     38.0    34.7     29.0   101.0      90.5
# 4   55.4  154.6     34.6    34.0     28.3    92.5      73.2

# %%
print(f"Shape: {body.shape}")
print(f"\ndtype:\n{body.dtypes}")
# Out:
# Shape: (4221, 7)
#
# dtype:
# BMXWT       float64
# BMXHT       float64
# BMXARML     float64
# BMXLEG      float64
# BMXARMC     float64
# BMXHIP      float64
# BMXWAIST    float64
# dtype: object

# %%
body.mean()
# Out:
# BMXWT        77.403791
# BMXHT       160.136792
# BMXARML      36.031035
# BMXLEG       37.157972
# BMXARMC      32.710329
# BMXHIP      109.178370
# BMXWAIST     98.488107
# dtype: float64

# %% [markdown]
# # Series

# %%
s = body.BMXWT
print(f"Shape: {s.shape}")
print(f"\nHead:\n{s.head()}")
# Out:
# Shape: (4221,)
#
# Head:
# 0    97.1
# 1    91.1
# 2    73.0
# 3    61.7
# 4    55.4
# Name: BMXWT, dtype: float64

# %%
s = body.loc[:, "BMXWT"]
print(f"Shape: {s.shape}")
print(f"\nHead:\n{s.head()}")
# Out:
# Shape: (4221,)
#
# Head:
# 0    97.1
# 1    91.1
# 2    73.0
# 3    61.7
# 4    55.4
# Name: BMXWT, dtype: float64

# %%
print(f".mean method: {s.mean()}")
print(f"numpy function: {np.mean(s)}")
# Out:
# .mean method: 77.40379057095475
# numpy function: 77.40379057095475

# %%
print(f"Shape: {s.shape}")
print(f"dtype: {s.dtype}")
print(f"Values: {s.values}")
print(f"Name: {s.name}")
# Out:
# Shape: (4221,)
# dtype: float64
# Values: [97.1 91.1 73.  ... 73.  78.6 82.8]
# Name: BMXWT

# %% [markdown]
# # Rows (index) & Columns

# %%
body
# Out:
#       BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 0      97.1  160.2     34.7    40.8     35.8   126.1     117.9
# 1      91.1  152.7     33.5    33.0     38.5   125.5     103.1
# 2      73.0  161.2     37.4    38.0     31.8   106.2      92.0
# 3      61.7  157.4     38.0    34.7     29.0   101.0      90.5
# 4      55.4  154.6     34.6    34.0     28.3    92.5      73.2
# ...     ...    ...      ...     ...      ...     ...       ...
# 4216   66.8  157.0     32.6    38.4     30.7   103.8      92.5
# 4217  116.9  167.4     42.2    43.0     40.7   128.4     120.0
# 4218   73.0  159.6     36.2    37.0     31.4   104.6      99.3
# 4219   78.6  168.5     38.1    40.2     36.0   102.4      98.5
# 4220   82.8  147.8     34.8    32.8     39.5   121.4     110.0
#
# [4221 rows x 7 columns]

# %%
# The index slot of a data frame stores an object of class Index (or one of its
# derivatives) that gives the row names
print(body.index)
# Out:
# RangeIndex(start=0, stop=4221, step=1)

# %%
print(body.columns)
# Out:
# Index(['BMXWT', 'BMXHT', 'BMXARML', 'BMXLEG', 'BMXARMC', 'BMXHIP', 'BMXWAIST'], dtype='object')

# %%
df
# Out:
#       a    b      c     d      e          f                    g
# 0  0.44  1.0   True     A   spam 2021-01-01               [spam]
# 1  0.06  2.5   True     B   spam 2022-02-02        [bacon, spam]
# 2  0.40  NaN  False     C  bacon 2023-03-03                 None
# 3  0.74  4.0  False  None   spam 2024-04-04  [eggs, bacon, spam]
# 4  0.18  NaN   True     E   eggs 2025-05-05                [ham]

# %%
df2 = df.set_index("e")
df2
# Out:
#           a    b      c     d          f                    g
# e
# spam   0.44  1.0   True     A 2021-01-01               [spam]
# spam   0.06  2.5   True     B 2022-02-02        [bacon, spam]
# bacon  0.40  NaN  False     C 2023-03-03                 None
# spam   0.74  4.0  False  None 2024-04-04  [eggs, bacon, spam]
# eggs   0.18  NaN   True     E 2025-05-05                [ham]

# %%
print(df2.index.name)
# Out:
# e

# %%
df2.rename_axis("new_column").reset_index()
# Out:
#   new_column     a    b      c     d          f                    g
# 0       spam  0.44  1.0   True     A 2021-01-01               [spam]
# 1       spam  0.06  2.5   True     B 2022-02-02        [bacon, spam]
# 2      bacon  0.40  NaN  False     C 2023-03-03                 None
# 3       spam  0.74  4.0  False  None 2024-04-04  [eggs, bacon, spam]
# 4       eggs  0.18  NaN   True     E 2025-05-05                [ham]

# %%
df2
# Out:
#           a    b      c     d          f                    g
# e
# spam   0.44  1.0   True     A 2021-01-01               [spam]
# spam   0.06  2.5   True     B 2022-02-02        [bacon, spam]
# bacon  0.40  NaN  False     C 2023-03-03                 None
# spam   0.74  4.0  False  None 2024-04-04  [eggs, bacon, spam]
# eggs   0.18  NaN   True     E 2025-05-05                [ham]

# %%
df2.reset_index(drop=True)
# Out:
#       a    b      c     d          f                    g
# 0  0.44  1.0   True     A 2021-01-01               [spam]
# 1  0.06  2.5   True     B 2022-02-02        [bacon, spam]
# 2  0.40  NaN  False     C 2023-03-03                 None
# 3  0.74  4.0  False  None 2024-04-04  [eggs, bacon, spam]
# 4  0.18  NaN   True     E 2025-05-05                [ham]

# %%
df2.rename(columns={"a": "spam"})
# Out:
#        spam    b      c     d          f                    g
# e
# spam   0.44  1.0   True     A 2021-01-01               [spam]
# spam   0.06  2.5   True     B 2022-02-02        [bacon, spam]
# bacon  0.40  NaN  False     C 2023-03-03                 None
# spam   0.74  4.0  False  None 2024-04-04  [eggs, bacon, spam]
# eggs   0.18  NaN   True     E 2025-05-05                [ham]

# %% [markdown]
# # groupby

# %%
nhanes = pd.read_csv(
    "data/nhanes_p_demo_bmx_2020.csv",
    comment="#").rename({
        "BMXBMI": "bmival",
        "RIAGENDR": "gender",
        "DMDBORN4": "usborn"
    }, axis=1)

# %%
nhanes
# Out:
#          SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0      109263         4    NaN    NaN       NaN       NaN      NaN      NaN
# 1      109264         1   42.2    NaN       NaN       NaN      NaN      NaN
# 2      109265         1   12.0    NaN      91.6       NaN      NaN      NaN
# 3      109266         1   97.1    NaN       NaN       NaN      NaN      NaN
# 4      109269         3   13.6    NaN      90.9       NaN      NaN      NaN
# ...       ...       ...    ...    ...       ...       ...      ...      ...
# 14295  124818         1  108.8    NaN       NaN       NaN      NaN      NaN
# 14296  124819         1   15.4    NaN      94.9       NaN      NaN      NaN
# 14297  124820         1   22.9    NaN       NaN       NaN      NaN      NaN
# 14298  124821         1   79.5    NaN       NaN       NaN      NaN      NaN
# 14299  124822         1   59.7    NaN       NaN       NaN      NaN      NaN
#
#        BMXHT  BMIHT  ...  FIAINTRP  MIALANG  MIAPROXY  MIAINTRP  AIALANGA  \
# 0        NaN    NaN  ...       2.0      NaN       NaN       NaN       NaN
# 1      154.7    NaN  ...       2.0      1.0       2.0       2.0       1.0
# 2       89.3    NaN  ...       2.0      NaN       NaN       NaN       NaN
# 3      160.2    NaN  ...       2.0      1.0       2.0       2.0       1.0
# 4        NaN    1.0  ...       2.0      NaN       NaN       NaN       NaN
# ...      ...    ...  ...       ...      ...       ...       ...       ...
# 14295  168.7    3.0  ...       2.0      1.0       2.0       2.0       1.0
# 14296   93.7    NaN  ...       2.0      NaN       NaN       NaN       NaN
# 14297  123.3    NaN  ...       2.0      NaN       NaN       NaN       NaN
# 14298  176.4    NaN  ...       2.0      1.0       2.0       2.0       1.0
# 14299  167.5    NaN  ...       NaN      2.0       2.0       2.0       NaN
#
#            WTINTPRP      WTMECPRP  SDMVPSU  SDMVSTRA  INDFMPIR
# 0       7891.762435   8951.815567        3       156      4.66
# 1      11689.747264  12271.157043        1       155      0.83
# 2      16273.825939  16658.764203        1       157      3.06
# 3       7825.646112   8154.968193        2       168      5.00
# 4       5906.250521   6848.271782        2       152      0.96
# ...             ...           ...      ...       ...       ...
# 14295  21586.596728  21666.889837        1       166      3.82
# 14296   1664.919253   1838.169709        2       171      0.07
# 14297  14819.783161  16497.806674        1       157      1.22
# 14298   4666.817952   4853.430230        1       158      3.71
# 14299  14024.476634  15195.796658        1       149       NaN
#
# [14300 rows x 50 columns]

# %%
res = nhanes.groupby(["gender","usborn"])["bmival"].mean()
res
# Out:
# gender  usborn
# 1       1         25.734110
#         2         27.405251
# 2       1         27.120261
#         2         27.579448
#         77        28.725000
#         99        32.600000
# Name: bmival, dtype: float64

# %%
res = res.reset_index()
res
# Out:
#    gender  usborn     bmival
# 0       1       1  25.734110
# 1       1       2  27.405251
# 2       2       1  27.120261
# 3       2       2  27.579448
# 4       2      77  28.725000
# 5       2      99  32.600000

# %% [markdown]
# # Aggregating DataFrame

# %%
df = pd.DataFrame(
    dict(u = np.round(np.random.rand(5), 2),
         v = np.round(np.random.randn(5), 2),
         w = ["spam", "bacon", "spam", "eggs", "sausage"]),
    index=["a", "b", "c", "d", "e"]
)
df
# Out:
#       u     v        w
# a  0.18  0.74     spam
# b  0.53  1.49    bacon
# c  0.53 -0.94     spam
# d  0.63  1.18     eggs
# e  0.85 -1.25  sausage

# %%
u = df.loc[:, "u"]
print(u)
# Out:
# a    0.18
# b    0.53
# c    0.53
# d    0.63
# e    0.85
# Name: u, dtype: float64

# %%
np.quantile(u, [0, 0.5, 1])
# Out:
# array([0.18, 0.53, 0.85])

# %%
uv = df.loc[:, ["u", "v"]]
uv
# Out:
#       u     v
# a  0.18  0.74
# b  0.53  1.49
# c  0.53 -0.94
# d  0.63  1.18
# e  0.85 -1.25

# %%
np.quantile(uv, [0, 0.5, 1], axis=0)
# Out:
# array([[ 0.18, -1.25],
#        [ 0.53,  0.74],
#        [ 0.85,  1.49]])

# %%
df.mean(numeric_only=True)
# Out:
# u    0.544
# v    0.244
# dtype: float64

# %%
df.quantile([0, 0.5, 1], numeric_only=True)
# Out:
#         u     v
# 0.0  0.18 -1.25
# 0.5  0.53  0.74
# 1.0  0.85  1.49

# %%
df.median(numeric_only=True)
# Out:
# u    0.53
# v    0.74
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# u    0.18
# v   -1.25
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# u    0.85
# v    1.49
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# u    0.05848
# v    1.57713
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# u    0.241826
# v    1.255838
# dtype: float64

# %%
df.skew(numeric_only=True)
# Out:
# u   -0.558188
# v   -0.445562
# dtype: float64

# %%
def q25(x):
    return x.quantile(0.25)
q25.__name__ = "25%"


def q50(x):
    return x.quantile(0.5)
q50.__name__ = "50%"


def q75(x):
    return x.quantile(0.75)
q75.__name__ = "75%"

# %%
df.loc[:, ["u", "v"]].agg(["count", "mean", "std", "min", q25, q50, q75, "max"])
# Out:
#               u         v
# count  5.000000  5.000000
# mean   0.544000  0.244000
# std    0.241826  1.255838
# min    0.180000 -1.250000
# 25%    0.530000 -0.940000
# 50%    0.530000  0.740000
# 75%    0.630000  1.180000
# max    0.850000  1.490000

# %%
df.describe()
# Out:
#               u         v
# count  5.000000  5.000000
# mean   0.544000  0.244000
# std    0.241826  1.255838
# min    0.180000 -1.250000
# 25%    0.530000 -0.940000
# 50%    0.530000  0.740000
# 75%    0.630000  1.180000
# max    0.850000  1.490000

# %% [markdown]
# # Transform DataFrame

# %%
df = pd.DataFrame(
    dict(u = np.round(np.random.rand(5), 2),
         v = np.round(np.random.randn(5), 2),
         w = ["spam", "bacon", "spam", "eggs", "sausage"]),
    index=["a", "b", "c", "d", "e"]
)

df
# Out:
#       u     v        w
# a  0.29 -0.64     spam
# b  0.63 -2.75    bacon
# c  0.09 -0.23     spam
# d  0.43 -0.70     eggs
# e  0.43 -1.77  sausage

# %%
np.exp(df.u)
# Out:
# a    1.336427
# b    1.877611
# c    1.094174
# d    1.537258
# e    1.537258
# Name: u, dtype: float64

# %%
np.exp(df.loc[:, ["u", "v"]])
# Out:
#           u         v
# a  1.336427  0.527292
# b  1.877611  0.063928
# c  1.094174  0.794534
# d  1.537258  0.496585
# e  1.537258  0.170333

# %%
u = df.u

# standardized version of u
u_s = (u - np.mean(u)) / np.std(u)

print(u_s)
# Out:
# a   -0.470280
# b    1.433235
# c   -1.589995
# d    0.313520
# e    0.313520
# Name: u, dtype: float64

# %%
df.loc[:, "u"] > df.loc[:, "v"]
# Out:
# a    True
# b    True
# c    True
# d    True
# e    True
# dtype: bool

# %%
# standardized version of u and v
df.loc[:, ["u", "v"]].apply( lambda x: (x-np.mean(x))/np.std(x) )
# Out:
#           u         v
# a -0.470280  0.628389
# b  1.433235 -1.665556
# c -1.589995  1.074131
# d  0.313520  0.563158
# e  0.313520 -0.600122

# %%
df.loc[:, ["u_s", "v_s"]] = np.array(df.loc[:, ["u", "v"]].apply(lambda x: (x-np.mean(x))/np.std(x)))
df
# Out:
#       u     v        w       u_s       v_s
# a  0.29 -0.64     spam -0.470280  0.628389
# b  0.63 -2.75    bacon  1.433235 -1.665556
# c  0.09 -0.23     spam -1.589995  1.074131
# d  0.43 -0.70     eggs  0.313520  0.563158
# e  0.43 -1.77  sausage  0.313520 -0.600122

# %%
df.loc[:, "uv_squared"] = (df.loc[:, "u"] * df.loc[:, "v"])**2
df
# Out:
#       u     v        w       u_s       v_s  uv_squared
# a  0.29 -0.64     spam -0.470280  0.628389    0.034447
# b  0.63 -2.75    bacon  1.433235 -1.665556    3.001556
# c  0.09 -0.23     spam -1.589995  1.074131    0.000428
# d  0.43 -0.70     eggs  0.313520  0.563158    0.090601
# e  0.43 -1.77  sausage  0.313520 -0.600122    0.579273

# %% [markdown]
# # Indexing Series

# %%
np.random.seed(123)
b = pd.Series(np.round(np.random.rand(10), 2))
b
# Out:
# 0    0.70
# 1    0.29
# 2    0.23
# 3    0.55
# 4    0.72
# 5    0.42
# 6    0.98
# 7    0.68
# 8    0.48
# 9    0.39
# dtype: float64

# %%
new_index = np.random.permutation(np.arange(10))
new_index
# Out:
# array([2, 1, 8, 7, 9, 4, 5, 6, 3, 0])

# %%
b.index = new_index
b
# Out:
# 2    0.70
# 1    0.29
# 8    0.23
# 7    0.55
# 9    0.72
# 4    0.42
# 5    0.98
# 6    0.68
# 3    0.48
# 0    0.39
# dtype: float64

# %%
c = b.copy()
c.index = list("abcdefghij")
c
# Out:
# a    0.70
# b    0.29
# c    0.23
# d    0.55
# e    0.72
# f    0.42
# g    0.98
# h    0.68
# i    0.48
# j    0.39
# dtype: float64

# %% [markdown]
# ## .loc

# %%
print(b.loc[0])
print(c.loc["j"])
# Out:
# 0.39
# 0.39

# %%
print(b.loc[[0, 1, 0]])
# Out:
# 0    0.39
# 1    0.29
# 0    0.39
# dtype: float64

# %%
print(c.loc[["j", "b", "j"]])
# Out:
# j    0.39
# b    0.29
# j    0.39
# dtype: float64

# %%
b.loc[(b > 0.4) & (b < 0.6)]
# Out:
# 7    0.55
# 4    0.42
# 3    0.48
# dtype: float64

# %% [markdown]
# ## .iloc

# %%
print(b.iloc[0])
# Out:
# 0.7

# %%
print(b.iloc[0:7]) # returns the 1st, 2nd, ..., 7th element
# Out:
# 2    0.70
# 1    0.29
# 8    0.23
# 7    0.55
# 9    0.72
# 4    0.42
# 5    0.98
# dtype: float64

# %%
print(b.iloc[1:7]) # returns the 2nd, 3rd, ..., 7th element
# Out:
# 1    0.29
# 8    0.23
# 7    0.55
# 9    0.72
# 4    0.42
# 5    0.98
# dtype: float64

# %% [markdown]
# # Indexing DataFrame

# %%
np.random.seed(123)
df = pd.DataFrame(dict(
    u = np.round(np.random.rand(5), 2),
    v = np.round(np.random.randn(5), 2),
    w = ["spam", "bacon", "spam", "eggs", "sausage"],
    x = [True, False, True, False, True]
))

df
# Out:
#       u     v        w      x
# 0  0.70  0.32     spam   True
# 1  0.29 -0.05    bacon  False
# 2  0.23 -0.20     spam   True
# 3  0.55  1.98     eggs  False
# 4  0.72 -1.62  sausage   True

# %%
df.loc[:, "u":"v"]
# Out:
#       u     v
# 0  0.70  0.32
# 1  0.29 -0.05
# 2  0.23 -0.20
# 3  0.55  1.98
# 4  0.72 -1.62

# %%
df.loc[ df.loc[:, "u"] > 0.5, "u":"v"]
# Out:
#       u     v
# 0  0.70  0.32
# 3  0.55  1.98
# 4  0.72 -1.62

# %%
df.iloc[:3, :]
# Out:
#       u     v      w      x
# 0  0.70  0.32   spam   True
# 1  0.29 -0.05  bacon  False
# 2  0.23 -0.20   spam   True

# %%
df.iloc[:3, :].loc[:, ["u", "v"]] # first 3 rows
# Out:
#       u     v
# 0  0.70  0.32
# 1  0.29 -0.05
# 2  0.23 -0.20

# %%
# DIFFERENT FROM THE CODE ABOVE
df.loc[:3, ["u", "v"]] # all rows up to index "3"
# Out:
#       u     v
# 0  0.70  0.32
# 1  0.29 -0.05
# 2  0.23 -0.20
# 3  0.55  1.98

# %%
df.loc[ (df.u > 0.5) & (df.u <= 0.7), ["u", "w"]]
# Out:
#       u     w
# 0  0.70  spam
# 3  0.55  eggs

# %%
df.drop(columns=["v"])
# Out:
#       u        w      x
# 0  0.70     spam   True
# 1  0.29    bacon  False
# 2  0.23     spam   True
# 3  0.55     eggs  False
# 4  0.72  sausage   True

# %%
df.loc[df.w.isin(["spam", "bacon"]), :]
# Out:
#       u     v      w      x
# 0  0.70  0.32   spam   True
# 1  0.29 -0.05  bacon  False
# 2  0.23 -0.20   spam   True

# %%
df.loc[:, "y"] = df.loc[:, "u"]**2

df
# Out:
#       u     v        w      x       y
# 0  0.70  0.32     spam   True  0.4900
# 1  0.29 -0.05    bacon  False  0.0841
# 2  0.23 -0.20     spam   True  0.0529
# 3  0.55  1.98     eggs  False  0.3025
# 4  0.72 -1.62  sausage   True  0.5184

# %%
df.insert(1, "new_col", df.u*-1)
df
# Out:
#       u  new_col     v        w      x       y
# 0  0.70    -0.70  0.32     spam   True  0.4900
# 1  0.29    -0.29 -0.05    bacon  False  0.0841
# 2  0.23    -0.23 -0.20     spam   True  0.0529
# 3  0.55    -0.55  1.98     eggs  False  0.3025
# 4  0.72    -0.72 -1.62  sausage   True  0.5184

# %%
df2 = pd.DataFrame(dict(
    u = [2],
    new_col = [-2],
    v = [0],
    w = ["cheese"],
    x = [False],
    y = [0],
), index=[999])

df2
# Out:
#      u  new_col  v       w      x  y
# 999  2       -2  0  cheese  False  0

# %%
pd.concat([df, df2])
# Out:
#         u  new_col     v        w      x       y
# 0    0.70    -0.70  0.32     spam   True  0.4900
# 1    0.29    -0.29 -0.05    bacon  False  0.0841
# 2    0.23    -0.23 -0.20     spam   True  0.0529
# 3    0.55    -0.55  1.98     eggs  False  0.3025
# 4    0.72    -0.72 -1.62  sausage   True  0.5184
# 999  2.00    -2.00  0.00   cheese  False  0.0000

# %% [markdown]
# # Sampling & Splitting

# %%
body
# Out:
#       BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 0      97.1  160.2     34.7    40.8     35.8   126.1     117.9
# 1      91.1  152.7     33.5    33.0     38.5   125.5     103.1
# 2      73.0  161.2     37.4    38.0     31.8   106.2      92.0
# 3      61.7  157.4     38.0    34.7     29.0   101.0      90.5
# 4      55.4  154.6     34.6    34.0     28.3    92.5      73.2
# ...     ...    ...      ...     ...      ...     ...       ...
# 4216   66.8  157.0     32.6    38.4     30.7   103.8      92.5
# 4217  116.9  167.4     42.2    43.0     40.7   128.4     120.0
# 4218   73.0  159.6     36.2    37.0     31.4   104.6      99.3
# 4219   78.6  168.5     38.1    40.2     36.0   102.4      98.5
# 4220   82.8  147.8     34.8    32.8     39.5   121.4     110.0
#
# [4221 rows x 7 columns]

# %% [markdown]
# ## Select N of rows

# %%
# 5 rows without replacement
body.sample(5, random_state=123)
# Out:
#       BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 4214   58.4  156.2     35.2    34.7     27.2    99.5      77.5
# 3361   73.7  161.0     36.5    34.5     29.0   107.6      98.2
# 3759   61.4  164.6     37.5    40.4     26.9    93.5      84.4
# 3733  120.4  158.8     33.5    34.6     40.5   147.2     129.3
# 1121  123.5  157.5     35.5    29.0     50.5   143.0     136.4

# %% [markdown]
# ## Select % of rows

# %%
body2 = body.head(10)
body2
# Out:
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 0   97.1  160.2     34.7    40.8     35.8   126.1     117.9
# 1   91.1  152.7     33.5    33.0     38.5   125.5     103.1
# 2   73.0  161.2     37.4    38.0     31.8   106.2      92.0
# 3   61.7  157.4     38.0    34.7     29.0   101.0      90.5
# 4   55.4  154.6     34.6    34.0     28.3    92.5      73.2
# 5   62.0  144.7     32.5    34.2     29.8   106.7      84.8
# 6   66.2  166.5     37.5    37.6     32.0    96.3      95.7
# 7   75.9  154.5     35.4    37.6     32.7   107.7      98.7
# 8   77.2  159.2     38.5    40.5     35.7   102.0      97.5
# 9   91.6  174.5     36.1    45.9     35.2   121.3     100.3

# %%
print(id(body))
print(id(body2))
# Out:
# 1747795306720
# 1747801852368

# %%
idx = np.random.permutation(body2.shape[0])
print(idx)
# Out:
# [2 1 8 7 0 4 5 6 3 9]

# %%
# select 80% rows, with replacement
k = int(body2.shape[0]*0.8)
body2.iloc[idx[:k], :]
# Out:
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 2   73.0  161.2     37.4    38.0     31.8   106.2      92.0
# 1   91.1  152.7     33.5    33.0     38.5   125.5     103.1
# 8   77.2  159.2     38.5    40.5     35.7   102.0      97.5
# 7   75.9  154.5     35.4    37.6     32.7   107.7      98.7
# 0   97.1  160.2     34.7    40.8     35.8   126.1     117.9
# 4   55.4  154.6     34.6    34.0     28.3    92.5      73.2
# 5   62.0  144.7     32.5    34.2     29.8   106.7      84.8
# 6   66.2  166.5     37.5    37.6     32.0    96.3      95.7

# %%
# select the other 20%
body2.iloc[idx[k:], :]
# Out:
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 3   61.7  157.4     38.0    34.7     29.0   101.0      90.5
# 9   91.6  174.5     36.1    45.9     35.2   121.3     100.3

# %% [markdown]
# # Method chaining

# %%
air = pd.read_csv("data/air_quality_2018_means.csv", comment="#")

# %%
air.head()
# Out:
#       sp_name param_id      value
# 0  Alphington      API   0.542584
# 1  Alphington   BPM2.5   7.848758
# 2  Alphington       CO   0.210884
# 3  Alphington    HPM10  17.835714
# 4  Alphington      NO2   9.558120

# %%
print(f"Shape: {air.shape}")
print(f"\ndtype:\n{air.dtypes}")
# Out:
# Shape: (56, 3)
#
# dtype:
# sp_name      object
# param_id     object
# value       float64
# dtype: object

# %%
air.param_id.isin(["BPM2.5", "NO2"]).head(10)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: param_id, dtype: bool

# %%
air.loc[air.param_id.isin(["BPM2.5", "NO2"]), :]
# Out:
#           sp_name param_id      value
# 1      Alphington   BPM2.5   7.848758
# 4      Alphington      NO2   9.558120
# 9    Altona North      NO2   9.467912
# 13      Churchill   BPM2.5   6.391230
# 15      Dandenong      NO2   9.800705
# 18      Footscray   BPM2.5   7.640948
# 20      Footscray      NO2  10.274531
# 25  Geelong South   BPM2.5   6.502762
# 27  Geelong South      NO2   5.681722
# 31  Melbourne CBD   BPM2.5   8.072998
# 33            Moe   BPM2.5   6.427079
# 38   Morwell East   BPM2.5   6.784596
# 42  Morwell South   BPM2.5   6.512849
# 44  Morwell South      NO2   5.124430
# 50      Traralgon   BPM2.5   8.024735
# 52      Traralgon      NO2   5.776333

# %%
# We can use backslash "\" or round brackets "()"
air.\
loc[air.param_id.isin(["BPM2.5", "NO2"]), :].\
reset_index(drop=True)
# Out:
#           sp_name param_id      value
# 0      Alphington   BPM2.5   7.848758
# 1      Alphington      NO2   9.558120
# 2    Altona North      NO2   9.467912
# 3       Churchill   BPM2.5   6.391230
# 4       Dandenong      NO2   9.800705
# 5       Footscray   BPM2.5   7.640948
# 6       Footscray      NO2  10.274531
# 7   Geelong South   BPM2.5   6.502762
# 8   Geelong South      NO2   5.681722
# 9   Melbourne CBD   BPM2.5   8.072998
# 10            Moe   BPM2.5   6.427079
# 11   Morwell East   BPM2.5   6.784596
# 12  Morwell South   BPM2.5   6.512849
# 13  Morwell South      NO2   5.124430
# 14      Traralgon   BPM2.5   8.024735
# 15      Traralgon      NO2   5.776333

# %%
(
    air.
    loc[air.param_id.isin(["BPM2.5", "NO2"]), :].
    reset_index(drop=True)
)
# Out:
#           sp_name param_id      value
# 0      Alphington   BPM2.5   7.848758
# 1      Alphington      NO2   9.558120
# 2    Altona North      NO2   9.467912
# 3       Churchill   BPM2.5   6.391230
# 4       Dandenong      NO2   9.800705
# 5       Footscray   BPM2.5   7.640948
# 6       Footscray      NO2  10.274531
# 7   Geelong South   BPM2.5   6.502762
# 8   Geelong South      NO2   5.681722
# 9   Melbourne CBD   BPM2.5   8.072998
# 10            Moe   BPM2.5   6.427079
# 11   Morwell East   BPM2.5   6.784596
# 12  Morwell South   BPM2.5   6.512849
# 13  Morwell South      NO2   5.124430
# 14      Traralgon   BPM2.5   8.024735
# 15      Traralgon      NO2   5.776333

# %%
air2 = (
    air.
    loc[air.param_id.isin(["BPM2.5", "NO2"]), :].
    reset_index(drop=True)
)

# %%
air2
# Out:
#           sp_name param_id      value
# 0      Alphington   BPM2.5   7.848758
# 1      Alphington      NO2   9.558120
# 2    Altona North      NO2   9.467912
# 3       Churchill   BPM2.5   6.391230
# 4       Dandenong      NO2   9.800705
# 5       Footscray   BPM2.5   7.640948
# 6       Footscray      NO2  10.274531
# 7   Geelong South   BPM2.5   6.502762
# 8   Geelong South      NO2   5.681722
# 9   Melbourne CBD   BPM2.5   8.072998
# 10            Moe   BPM2.5   6.427079
# 11   Morwell East   BPM2.5   6.784596
# 12  Morwell South   BPM2.5   6.512849
# 13  Morwell South      NO2   5.124430
# 14      Traralgon   BPM2.5   8.024735
# 15      Traralgon      NO2   5.776333

# %% [markdown]
# # Sorting

# %%
air2.sort_values("value", ascending=False)
# Out:
#           sp_name param_id      value
# 6       Footscray      NO2  10.274531
# 4       Dandenong      NO2   9.800705
# 1      Alphington      NO2   9.558120
# 2    Altona North      NO2   9.467912
# 9   Melbourne CBD   BPM2.5   8.072998
# 14      Traralgon   BPM2.5   8.024735
# 0      Alphington   BPM2.5   7.848758
# 5       Footscray   BPM2.5   7.640948
# 11   Morwell East   BPM2.5   6.784596
# 12  Morwell South   BPM2.5   6.512849
# 7   Geelong South   BPM2.5   6.502762
# 10            Moe   BPM2.5   6.427079
# 3       Churchill   BPM2.5   6.391230
# 15      Traralgon      NO2   5.776333
# 8   Geelong South      NO2   5.681722
# 13  Morwell South      NO2   5.124430

# %%
air2.sort_values(["param_id", "value"], ascending=[True, False])
# Out:
#           sp_name param_id      value
# 9   Melbourne CBD   BPM2.5   8.072998
# 14      Traralgon   BPM2.5   8.024735
# 0      Alphington   BPM2.5   7.848758
# 5       Footscray   BPM2.5   7.640948
# 11   Morwell East   BPM2.5   6.784596
# 12  Morwell South   BPM2.5   6.512849
# 7   Geelong South   BPM2.5   6.502762
# 10            Moe   BPM2.5   6.427079
# 3       Churchill   BPM2.5   6.391230
# 6       Footscray      NO2  10.274531
# 4       Dandenong      NO2   9.800705
# 1      Alphington      NO2   9.558120
# 2    Altona North      NO2   9.467912
# 15      Traralgon      NO2   5.776333
# 8   Geelong South      NO2   5.681722
# 13  Morwell South      NO2   5.124430

# %%
# air2.sort_values("value", ascending=False)
pd.DataFrame(dict(
    a1 = air2.value,
    a2 = np.argsort(air2.value)
))
# Out:
#            a1  a2
# 0    7.848758  13
# 1    9.558120   8
# 2    9.467912  15
# 3    6.391230   3
# 4    9.800705  10
# 5    7.640948   7
# 6   10.274531  12
# 7    6.502762  11
# 8    5.681722   5
# 9    8.072998   0
# 10   6.427079  14
# 11   6.784596   9
# 12   6.512849   2
# 13   5.124430   1
# 14   8.024735   4
# 15   5.776333   6

# %%
air2.iloc[np.argsort(air2.value), :]
# Out:
#           sp_name param_id      value
# 13  Morwell South      NO2   5.124430
# 8   Geelong South      NO2   5.681722
# 15      Traralgon      NO2   5.776333
# 3       Churchill   BPM2.5   6.391230
# 10            Moe   BPM2.5   6.427079
# 7   Geelong South   BPM2.5   6.502762
# 12  Morwell South   BPM2.5   6.512849
# 11   Morwell East   BPM2.5   6.784596
# 5       Footscray   BPM2.5   7.640948
# 0      Alphington   BPM2.5   7.848758
# 14      Traralgon   BPM2.5   8.024735
# 9   Melbourne CBD   BPM2.5   8.072998
# 2    Altona North      NO2   9.467912
# 1      Alphington      NO2   9.558120
# 4       Dandenong      NO2   9.800705
# 6       Footscray      NO2  10.274531

# %%
air2.sort_values("value", ascending=True)
# Out:
#           sp_name param_id      value
# 13  Morwell South      NO2   5.124430
# 8   Geelong South      NO2   5.681722
# 15      Traralgon      NO2   5.776333
# 3       Churchill   BPM2.5   6.391230
# 10            Moe   BPM2.5   6.427079
# 7   Geelong South   BPM2.5   6.502762
# 12  Morwell South   BPM2.5   6.512849
# 11   Morwell East   BPM2.5   6.784596
# 5       Footscray   BPM2.5   7.640948
# 0      Alphington   BPM2.5   7.848758
# 14      Traralgon   BPM2.5   8.024735
# 9   Melbourne CBD   BPM2.5   8.072998
# 2    Altona North      NO2   9.467912
# 1      Alphington      NO2   9.558120
# 4       Dandenong      NO2   9.800705
# 6       Footscray      NO2  10.274531

# %%
# The following 2 lines are equivalent
a1 = air2.iloc[np.argsort(air2.value), :]
a2 = air2.sort_values("value", ascending=True)

x1 = pd.Series(['X']).repeat(air2.shape[0])
x1.name = "X"
x1.index = a1.index

pd.concat([a1, x1, a2], axis=1)
# Out:
#           sp_name param_id      value  X        sp_name param_id      value
# 13  Morwell South      NO2   5.124430  X  Morwell South      NO2   5.124430
# 8   Geelong South      NO2   5.681722  X  Geelong South      NO2   5.681722
# 15      Traralgon      NO2   5.776333  X      Traralgon      NO2   5.776333
# 3       Churchill   BPM2.5   6.391230  X      Churchill   BPM2.5   6.391230
# 10            Moe   BPM2.5   6.427079  X            Moe   BPM2.5   6.427079
# 7   Geelong South   BPM2.5   6.502762  X  Geelong South   BPM2.5   6.502762
# 12  Morwell South   BPM2.5   6.512849  X  Morwell South   BPM2.5   6.512849
# 11   Morwell East   BPM2.5   6.784596  X   Morwell East   BPM2.5   6.784596
# 5       Footscray   BPM2.5   7.640948  X      Footscray   BPM2.5   7.640948
# 0      Alphington   BPM2.5   7.848758  X     Alphington   BPM2.5   7.848758
# 14      Traralgon   BPM2.5   8.024735  X      Traralgon   BPM2.5   8.024735
# 9   Melbourne CBD   BPM2.5   8.072998  X  Melbourne CBD   BPM2.5   8.072998
# 2    Altona North      NO2   9.467912  X   Altona North      NO2   9.467912
# 1      Alphington      NO2   9.558120  X     Alphington      NO2   9.558120
# 4       Dandenong      NO2   9.800705  X      Dandenong      NO2   9.800705
# 6       Footscray      NO2  10.274531  X      Footscray      NO2  10.274531

# %% [markdown]
# # Stacking and Unstacking (Long and Wide Forms)

# %%
# Long format (stacked)
air2
# Out:
#           sp_name param_id      value
# 0      Alphington   BPM2.5   7.848758
# 1      Alphington      NO2   9.558120
# 2    Altona North      NO2   9.467912
# 3       Churchill   BPM2.5   6.391230
# 4       Dandenong      NO2   9.800705
# 5       Footscray   BPM2.5   7.640948
# 6       Footscray      NO2  10.274531
# 7   Geelong South   BPM2.5   6.502762
# 8   Geelong South      NO2   5.681722
# 9   Melbourne CBD   BPM2.5   8.072998
# 10            Moe   BPM2.5   6.427079
# 11   Morwell East   BPM2.5   6.784596
# 12  Morwell South   BPM2.5   6.512849
# 13  Morwell South      NO2   5.124430
# 14      Traralgon   BPM2.5   8.024735
# 15      Traralgon      NO2   5.776333

# %%
# Wide format (unstacked)
air2.set_index(["sp_name", "param_id"])
# Out:
#                             value
# sp_name       param_id
# Alphington    BPM2.5     7.848758
#               NO2        9.558120
# Altona North  NO2        9.467912
# Churchill     BPM2.5     6.391230
# Dandenong     NO2        9.800705
# Footscray     BPM2.5     7.640948
#               NO2       10.274531
# Geelong South BPM2.5     6.502762
#               NO2        5.681722
# Melbourne CBD BPM2.5     8.072998
# Moe           BPM2.5     6.427079
# Morwell East  BPM2.5     6.784596
# Morwell South BPM2.5     6.512849
#               NO2        5.124430
# Traralgon     BPM2.5     8.024735
#               NO2        5.776333

# %%
# Wide format (unstacked)
air2.set_index(["sp_name", "param_id"]).unstack()
# Out:
#                   value
# param_id         BPM2.5        NO2
# sp_name
# Alphington     7.848758   9.558120
# Altona North        NaN   9.467912
# Churchill      6.391230        NaN
# Dandenong           NaN   9.800705
# Footscray      7.640948  10.274531
# Geelong South  6.502762   5.681722
# Melbourne CBD  8.072998        NaN
# Moe            6.427079        NaN
# Morwell East   6.784596        NaN
# Morwell South  6.512849   5.124430
# Traralgon      8.024735   5.776333

# %%
# Wide format (unstacked)
# .loc[...] to drop the last level of the hierarchy
air2_wide = air2.set_index(["sp_name", "param_id"]).unstack().loc[:, "value"]
air2_wide
# Out:
# param_id         BPM2.5        NO2
# sp_name
# Alphington     7.848758   9.558120
# Altona North        NaN   9.467912
# Churchill      6.391230        NaN
# Dandenong           NaN   9.800705
# Footscray      7.640948  10.274531
# Geelong South  6.502762   5.681722
# Melbourne CBD  8.072998        NaN
# Moe            6.427079        NaN
# Morwell East   6.784596        NaN
# Morwell South  6.512849   5.124430
# Traralgon      8.024735   5.776333

# %%
# Back to the long format
air2_wide.T
# Out:
# sp_name   Alphington  Altona North  Churchill  Dandenong  Footscray  \
# param_id
# BPM2.5      7.848758           NaN    6.39123        NaN   7.640948
# NO2         9.558120      9.467912        NaN   9.800705  10.274531
#
# sp_name   Geelong South  Melbourne CBD       Moe  Morwell East  Morwell South  \
# param_id
# BPM2.5         6.502762       8.072998  6.427079      6.784596       6.512849
# NO2            5.681722            NaN       NaN           NaN       5.124430
#
# sp_name   Traralgon
# param_id
# BPM2.5     8.024735
# NO2        5.776333

# %%
# Back to the long format
air2_wide.T.rename_axis(index="location", columns="param")
# Out:
# param     Alphington  Altona North  Churchill  Dandenong  Footscray  \
# location
# BPM2.5      7.848758           NaN    6.39123        NaN   7.640948
# NO2         9.558120      9.467912        NaN   9.800705  10.274531
#
# param     Geelong South  Melbourne CBD       Moe  Morwell East  Morwell South  \
# location
# BPM2.5         6.502762       8.072998  6.427079      6.784596       6.512849
# NO2            5.681722            NaN       NaN           NaN       5.124430
#
# param     Traralgon
# location
# BPM2.5     8.024735
# NO2        5.776333

# %%
# Back to the long format
air2_wide.T.rename_axis(index="location", columns="param").\
stack()
# Out:
# location  param
# BPM2.5    Alphington        7.848758
#           Churchill         6.391230
#           Footscray         7.640948
#           Geelong South     6.502762
#           Melbourne CBD     8.072998
#           Moe               6.427079
#           Morwell East      6.784596
#           Morwell South     6.512849
#           Traralgon         8.024735
# NO2       Alphington        9.558120
#           Altona North      9.467912
#           Dandenong         9.800705
#           Footscray        10.274531
#           Geelong South     5.681722
#           Morwell South     5.124430
#           Traralgon         5.776333
# dtype: float64

# %%
# Back to the long format
air2_wide.T.rename_axis(index="location", columns="param").\
stack().rename("value")
# Out:
# location  param
# BPM2.5    Alphington        7.848758
#           Churchill         6.391230
#           Footscray         7.640948
#           Geelong South     6.502762
#           Melbourne CBD     8.072998
#           Moe               6.427079
#           Morwell East      6.784596
#           Morwell South     6.512849
#           Traralgon         8.024735
# NO2       Alphington        9.558120
#           Altona North      9.467912
#           Dandenong         9.800705
#           Footscray        10.274531
#           Geelong South     5.681722
#           Morwell South     5.124430
#           Traralgon         5.776333
# Name: value, dtype: float64

# %%
# Back to the long format
air2_wide.T.rename_axis(index="location", columns="param").\
stack().rename("value").reset_index()
# Out:
#    location          param      value
# 0    BPM2.5     Alphington   7.848758
# 1    BPM2.5      Churchill   6.391230
# 2    BPM2.5      Footscray   7.640948
# 3    BPM2.5  Geelong South   6.502762
# 4    BPM2.5  Melbourne CBD   8.072998
# 5    BPM2.5            Moe   6.427079
# 6    BPM2.5   Morwell East   6.784596
# 7    BPM2.5  Morwell South   6.512849
# 8    BPM2.5      Traralgon   8.024735
# 9       NO2     Alphington   9.558120
# 10      NO2   Altona North   9.467912
# 11      NO2      Dandenong   9.800705
# 12      NO2      Footscray  10.274531
# 13      NO2  Geelong South   5.681722
# 14      NO2  Morwell South   5.124430
# 15      NO2      Traralgon   5.776333

# %% [markdown]
# # Merging

# %%
A = pd.DataFrame({
    "x": ["a0", "a1", "a2", "a3"],
    "y": ["b0", "b1", "b2", "b3"]
})

A
# Out:
#     x   y
# 0  a0  b0
# 1  a1  b1
# 2  a2  b2
# 3  a3  b3

# %%
B = pd.DataFrame({
    "x": ["a0", "a2", "a2", "a4"],
    "z": ["c0", "c1", "c2", "c3"]
})

B
# Out:
#     x   z
# 0  a0  c0
# 1  a2  c1
# 2  a2  c2
# 3  a4  c3

# %%
# Inner join
pd.merge(A, B, on="x")
# Out:
#     x   y   z
# 0  a0  b0  c0
# 1  a2  b2  c1
# 2  a2  b2  c2

# %%
# Left join
pd.merge(A, B, how="left", on="x")
# Out:
#     x   y    z
# 0  a0  b0   c0
# 1  a1  b1  NaN
# 2  a2  b2   c1
# 3  a2  b2   c2
# 4  a3  b3  NaN

# %%
# Right join
pd.merge(A, B, how="right", on="x")
# Out:
#     x    y   z
# 0  a0   b0  c0
# 1  a2   b2  c1
# 2  a2   b2  c2
# 3  a4  NaN  c3

# %%
# Full outer join
pd.merge(A, B, how="outer", on="x")
# Out:
#     x    y    z
# 0  a0   b0   c0
# 1  a1   b1  NaN
# 2  a2   b2   c1
# 3  a2   b2   c2
# 4  a3   b3  NaN
# 5  a4  NaN   c3
